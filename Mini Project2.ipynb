# %%
import pandas as pd
temp_df = pd.DataFrame({
    "city":["Hyderbad","Viaywada","Vishakapatnam","Bangalore"],
    "temperature":[32,45,30,35]
})
temp_df
# Out:
#             city  temperature
# 0       Hyderbad           32
# 1       Viaywada           45
# 2  Vishakapatnam           30
# 3      Bangalore           35

# %%
temp_df.temperature.min()
# Out:
# 30

# %%
temp_df.temperature.max()
# Out:
# 45

# %%
temp_df.temperature.mean()
# Out:
# np.float64(35.5)

# %%
temp_df.temperature.std()
# Out:
# 6.658328118479393

# %%
temp_df.temperature.var()
# Out:
# 44.333333333333336

# %%
temp_df.temperature.count()
# Out:
# np.int64(4)

# %%
temp_df.temperature.sum()
# Out:
# np.int64(142)

# %%
temp_df.temperature.describe()
# Out:
# count     4.000000
# mean     35.500000
# std       6.658328
# min      30.000000
# 25%      31.500000
# 50%      33.500000
# 75%      37.500000
# max      45.000000
# Name: temperature, dtype: float64

# %%
temp_df.temperature.dtype
# Out:
# dtype('int64')
