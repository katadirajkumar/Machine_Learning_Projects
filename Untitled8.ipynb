# %% [raw]
# import csv
# with open(["data.csv","age","city"])as file:
#     writer.writerow(["ani","21","vizag"])
#     writer.writerow(["kavini","22","kkd"])
#     writer.writerow(["mini","23","rajam"])
